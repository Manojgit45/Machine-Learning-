# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns

# %%
import nltk
from nltk.tokenize import word_tokenize,regexp_tokenize
import string
nltk.download('punkt_tab')
from nltk.corpus import stopwords
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
df = pd.read_csv('/content/imdb.csv')

# %%
df.head()
# Out:
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %%
import re
def clean_text(text):
  text = text.lower()
  text = re.sub(r'<.*?>','',text)
  text = re.sub(r'(?<!\w)-|-(?!\w)','',text)
  text = re.sub(r'[^\w\s-]','',text)
  stop_words = set(stopwords.words('english'))
  filtered = ' '.join([w for w in text.split() if w not in stop_words])
  filtered = filtered.replace('-','')
  filtered = filtered.strip()
  return filtered

# %%
df['review'] = df['review'].apply(clean_text)

# %%
df.head()
# Out:
#                                               review sentiment
# 0  one reviewers mentioned watching 1 oz episode ...  positive
# 1  wonderful little production filming technique ...  positive
# 2  thought wonderful way spend time hot summer we...  positive
# 3  basically theres family little boy jake thinks...  negative
# 4  petter matteis love time money visually stunni...  positive

# %%
X = df['review']
y= df['sentiment']

# %% [markdown]
# Create an instance of TF-IDF Vectorization with max features set to 5000 in variable tfidf_vectorizer.
# Fit and transform the data extracted and store it in X_tfidf.
# Split the dataset into training and testing named X_train, X_test, y_train, y_test with the newly transformed data and the labels with a test size of 20% and random state set to 42.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer,CountVectorizer

# %%
tfidf_vectorizer = TfidfVectorizer(max_features=5000)

# %%
X_tfidf = tfidf_vectorizer.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X_tfidf, y, test_size=0.2, random_state=42)

# %% [markdown]
# Initialize SVM classifier with seed value of 42 stored in variable svm.
# Fit the training data to the classifier and gather the predictions against the testing data and store it in y_pred.

# %%
from sklearn.svm import SVC

# %%
svm = SVC(random_state=42)
svm.fit(X_train,y_train)
# Out:
# SVC(random_state=42)

# %%
y_pred = svm.predict(X_test)

# %% [markdown]
# Evaluate the score for predictions against the testing data and store the output in accuracy.
# Get the classification report and of the predictions and the testing data as a dictionary and store it in report.

# %%
from sklearn.metrics import classification_report,accuracy_score

# %%
accuracy=svm.score(X_test,y_test)
accuracy
# Out:
# 0.8625

# %%
report = classification_report(y_test,y_pred,output_dict=True)

# %%
report
# Out:
# {'negative': {'precision': 0.8645833333333334,
#   'recall': 0.8512820512820513,
#   'f1-score': 0.8578811369509044,
#   'support': 195.0},
#  'positive': {'precision': 0.8605769230769231,
#   'recall': 0.8731707317073171,
#   'f1-score': 0.8668280871670703,
#   'support': 205.0},
#  'accuracy': 0.8625,
#  'macro avg': {'precision': 0.8625801282051282,
#   'recall': 0.8622263914946842,
#   'f1-score': 0.8623546120589873,
#   'support': 400.0},
#  'weighted avg': {'precision': 0.8625300480769232,
#   'recall': 0.8625,
#   'f1-score': 0.8624664489366893,
#   'support': 400.0}}

# %% [markdown]
# **Task 6 : Word Frequency Analysis , Average Word Length Calculation**
# Get the most common Top 10 words from the cleaned review data and store it as a dictionary.
# Name the dictionary as wc_dict. Example: {word1: count1, word2: count2}
# Use tokenization and counting methods to calculate word frequencies.

# %%
from nltk.tokenize import word_tokenize
from collections import Counter
from nltk.probability import FreqDist
all_reviews = ' '.join(df['review'].astype(str))
#all_reviews
words = word_tokenize(all_reviews)
#words
word_counts = Counter(words)
wc_dict = dict(word_counts.most_common(10))
wc_dict
# Out:
# {'movie': 3373,
#  'film': 2885,
#  'one': 1916,
#  'like': 1489,
#  'good': 1088,
#  'even': 992,
#  'would': 981,
#  'see': 939,
#  'really': 888,
#  'story': 862}

# %% [markdown]
# **Average Word Length Calculation**
# Compute the average word length in characters across the text dataset and store the result in avg_word_length.
# Tokenize the text and calculate the average length of tokens.

# %%
avg_word_length = sum(len(word) for word in words) / len(words)
print(np.round(avg_word_length,2))
#
# Out:
# 5.99

# %%
texts = ["test1 passed", "test1 failed", "test2 passed", "test2 failed", "test3 passed",
         "test3 failed", "test4 passed", "test4 failed", "test5 passed", "test5 failed", "test6 passed", "test6 failed",
         "test7 passed", "test7 failed", "test8 passed", "test8 failed", "test9 passed", "test9 failed", "test10 passed", "test10 failed",
         "test11 passed", "test11 failed", "test12 passed", "test12 failed"]

# %%
import hashlib
import pickle
def geth(obj):
    obj = str(obj).encode()
    m = hashlib.md5()
    m.update(bytes(obj))
    return m.hexdigest()

# %%
aobj = geth(texts[0])
with open("ans1.pckl", 'wb') as f:
          pickle.dump(aobj, f,protocol=pickle.HIGHEST_PROTOCOL)

# %%
with(open('ans1.pckl','rb')) as f:
  print(pickle.load(f))
# Out:
# 02a5b60d8e7327ccdd7cb3768b4fde30
