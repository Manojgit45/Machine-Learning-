# %% [markdown]
# ___
#
# <a href='https://www.udemy.com/user/joseportilla/'><img src='../Pierian_Data_Logo.png'/></a>
# ___
# <center><em>Copyright by Pierian Data Inc.</em></center>
# <center><em>For more information, visit us at <a href='http://www.pieriandata.com'>www.pieriandata.com</a></em></center>

# %% [markdown]
# # Support Vector Machines
# ## Exercise
#
# ## [Fraud in Wine](https://en.wikipedia.org/wiki/Wine_fraud)
#
# Wine fraud relates to the commercial aspects of wine. The most prevalent type of fraud is one where wines are adulterated, usually with the addition of cheaper products (e.g. juices) and sometimes with harmful chemicals and sweeteners (compensating for color or flavor).
#
# Counterfeiting and the relabelling of inferior and cheaper wines to more expensive brands is another common type of wine fraud.
#
# <img src="wine.jpg">
#
# ## Project Goals
#
# A distribution company that was recently a victim of fraud has completed an audit of various samples of wine through the use of chemical analysis on samples. The distribution company specializes in exporting extremely high quality, expensive wines, but was defrauded by a supplier who was attempting to pass off cheap, low quality wine as higher grade wine. The distribution company has hired you to attempt to create a machine learning model that can help detect low quality (a.k.a "fraud") wine samples. They want to know if it is even possible to detect such a difference.
#
#
# Data Source: *P. Cortez, A. Cerdeira, F. Almeida, T. Matos and J. Reis. Modeling wine preferences by data mining from physicochemical properties.
# In Decision Support Systems, Elsevier, 47(4):547-553, 2009.*
#
# ---
# ---
#
# **TASK: Your overall goal is to use the wine dataset shown below to develop a machine learning model that attempts to predict if a wine is "Legit" or "Fraud" based on various chemical features. Complete the tasks below to follow along with the project.**
#
# ---
# ---

# %% [markdown]
# ## Complete the Tasks in bold
#
# **TASK: Run the cells below to import the libraries and load the dataset.**

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/content/wine_fraud.csv")

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol quality type
# 0      9.4   Legit  red
# 1      9.8   Legit  red
# 2      9.8   Legit  red
# 3      9.8   Legit  red
# 4      9.4   Legit  red

# %% [markdown]
# **TASK: What are the unique variables in the target column we are trying to predict (quality)?**

# %%
df['quality'].unique()
# Out:
# array(['Legit', 'Fraud'], dtype=object)

# %%
# Out:
# array(['Legit', 'Fraud'], dtype=object)

# %% [markdown]
# **TASK: Create a countplot that displays the count per category of Legit vs Fraud. Is the label/target balanced or unbalanced?**

# %%
# CODE HERE
sns.countplot(data=df,x='quality',palette='coolwarm')
# Out:
# <ipython-input-7-f3f9af898aa7>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df,x='quality',palette='coolwarm')
# <Axes: xlabel='quality', ylabel='count'>

# %%
# Out:
# <AxesSubplot:xlabel='quality', ylabel='count'>

# %% [markdown]
# **TASK: Let's find out if there is a difference between red and white wine when it comes to fraud. Create a countplot that has the wine *type* on the x axis with the hue separating columns by Fraud vs Legit.**

# %%
# CODE HERE
sns.countplot(data=df,x='type',hue='quality',palette='viridis')
# Out:
# <Axes: xlabel='type', ylabel='count'>

# %%
# Out:
# <AxesSubplot:xlabel='type', ylabel='count'>

# %% [markdown]
# **TASK: What percentage of red wines are Fraud? What percentage of white wines are fraud?**

# %%
percent_red = 100*df[df['type']=='red']['quality'].value_counts()/df[df['type']=='red']['quality'].count()
percent_white = 100*df[df['type']=='white']['quality'].value_counts()/df[df['type']=='white']['quality'].count()

# %%
print(percent_red.Fraud)
# Out:
# 3.9399624765478425

# %%
print(percent_white.Fraud)
# Out:
# 3.736218864842793

# %% [markdown]
# **TASK: Calculate the correlation between the various features and the "quality" column. To do this you may need to map the column to 0 and 1 instead of a string.**

# %%
# CODE HERE
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['quality'] = le.fit_transform(df['quality'])
df['type'] = le.fit_transform(df['type'])

# %%
df.corr()['quality']
# Out:
# fixed acidity          -0.021794
# volatile acidity       -0.151228
# citric acid             0.061789
# residual sugar          0.048756
# chlorides              -0.034499
# free sulfur dioxide     0.085204
# total sulfur dioxide    0.035252
# density                -0.016351
# pH                     -0.020107
# sulphates               0.034046
# alcohol                 0.051141
# quality                 1.000000
# type                    0.004598
# Name: quality, dtype: float64

# %%
# Out:
# fixed acidity           0.021794
# volatile acidity        0.151228
# citric acid            -0.061789
# residual sugar         -0.048756
# chlorides               0.034499
# free sulfur dioxide    -0.085204
# total sulfur dioxide   -0.035252
# density                 0.016351
# pH                      0.020107
# sulphates              -0.034046
# alcohol                -0.051141
# Fraud                   1.000000
# Name: Fraud, dtype: float64

# %% [markdown]
# **TASK: Create a bar plot of the correlation values to Fraudlent wine.**

# %%
# CODE HERE
plt.figure(figsize=(6,3))
df.corr()['quality'].sort_values().drop('quality').plot(kind='bar')
# Out:
# <Axes: >

# %%
# Out:
# <AxesSubplot:>

# %% [markdown]
# **TASK: Create a clustermap with seaborn to explore the relationships between variables.**

# %%
# CODE HERE
sns.clustermap(df.corr(),cmap='viridis')

# %% [markdown]
# ----
# ## Machine Learning Model
#
# **TASK: Convert the categorical column "type" from a string or "red" or "white" to dummy variables:**

# %%
# CODE HERE

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# **TASK: Separate out the data into X features and y target label ("quality" column)**

# %%
X = df.drop('quality',axis=1)
y = df['quality']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=101)

# %% [markdown]
# **TASK: Perform a Train|Test split on the data, with a 10% test size. Note: The solution uses a random state of 101**

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()

# %% [markdown]
# **TASK: Scale the X train and X test data.**

# %%
X_train_scaled = sc.fit_transform(X_train)
X_test_scaled =sc.transform(X_test)

# %%
from sklearn.svm import SVC

# %% [markdown]
# **TASK: Create an instance of a Support Vector Machine classifier. Previously we have left this model "blank", (e.g. with no parameters). However, we already know that the classes are unbalanced, in an attempt to help alleviate this issue, we can automatically adjust weights inversely proportional to class frequencies in the input data with a argument call in the SVC() call. Check out the [documentation for SVC](https://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html) online and look up what the argument\parameter is.**

# %%
# CODE HERE
svc = SVC(class_weight='balanced')

# %%
svc.fit(X_train_scaled,y_train)
# Out:
# SVC(class_weight='balanced')

# %%
y_pred = svc.predict(X_test_scaled)

# %% [markdown]
# **TASK: Use a GridSearchCV to run a grid search for the best C and gamma parameters.**

# %%
# CODE HERE
from sklearn.model_selection import GridSearchCV

# %%
params = {'C':[0.1,1,10,100,1000],'gamma':[1,0.1,0.01,0.001,0.0001]}

# %%
grid = GridSearchCV(SVC(),params,verbose=3)

# %%
grid.fit(X_train_scaled,y_train)
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [CV 1/5] END ....................C=0.1, gamma=1;, score=0.962 total time=   0.8s
# [CV 2/5] END ....................C=0.1, gamma=1;, score=0.962 total time=   0.9s
# [CV 3/5] END ....................C=0.1, gamma=1;, score=0.963 total time=   0.9s
# [CV 4/5] END ....................C=0.1, gamma=1;, score=0.962 total time=   0.8s
# [CV 5/5] END ....................C=0.1, gamma=1;, score=0.962 total time=   0.8s
# [CV 1/5] END ..................C=0.1, gamma=0.1;, score=0.962 total time=   0.2s
# [CV 2/5] END ..................C=0.1, gamma=0.1;, score=0.962 total time=   0.2s
# [CV 3/5] END ..................C=0.1, gamma=0.1;, score=0.963 total time=   0.2s
# [CV 4/5] END ..................C=0.1, gamma=0.1;, score=0.962 total time=   0.3s
# [CV 5/5] END ..................C=0.1, gamma=0.1;, score=0.962 total time=   0.3s
# [CV 1/5] END .................C=0.1, gamma=0.01;, score=0.962 total time=   0.2s
# [CV 2/5] END .................C=0.1, gamma=0.01;, score=0.962 total time=   0.2s
# [CV 3/5] END .................C=0.1, gamma=0.01;, score=0.963 total time=   0.2s
# [CV 4/5] END .................C=0.1, gamma=0.01;, score=0.962 total time=   0.2s
# [CV 5/5] END .................C=0.1, gamma=0.01;, score=0.962 total time=   0.2s
# [CV 2/5] END ...............C=100, gamma=0.0001;, score=0.962 total time=   0.3s
# [CV 3/5] END ...............C=100, gamma=0.0001;, score=0.963 total time=   0.4s
# [CV 4/5] END ...............C=100, gamma=0.0001;, score=0.962 total time=   0.4s
# [CV 5/5] END ...............C=100, gamma=0.0001;, score=0.962 total time=   0.4s
# [CV 1/5] END ...................C=1000, gamma=1;, score=0.962 total time=   0.7s
# [CV 2/5] END ...................C=1000, gamma=1;, score=0.964 total time=   0.7s
# [CV 3/5] END ...................C=1000, gamma=1;, score=0.959 total time=   0.7s
# [CV 4/5] END ...................C=1000, gamma=1;, score=0.966 total time=   0.8s
# [CV 5/5] END ...................C=1000, gamma=1;, score=0.962 total time=   1.2s
# [CV 1/5] END .................C=1000, gamma=0.1;, score=0.938 total time=   1.0s
# [CV 2/5] END .................C=1000, gamma=0.1;, score=0.939 total time=   1.1s
# [CV 3/5] END .................C=1000, gamma=0.1;, score=0.945 total time=   1.0s
# [CV 4/5] END .................C=1000, gamma=0.1;, score=0.949 total time=   0.7s
# [CV 5/5] END .................C=1000, gamma=0.1;, score=0.948 total time=   0.6s
# [CV 1/5] END ................C=1000, gamma=0.01;, score=0.962 total time=   1.3s
# [CV 2/5] END ................C=1000, gamma=0.01;, score=0.964 total time=   1.5s
# [CV 3/5] END ................C=1000, gamma=0.01;, score=0.962 total time=   1.3s
# [CV 4/5] END ................C=1000, gamma=0.01;, score=0.959 total time=   1.3s
# [CV 5/5] END ................C=1000, gamma=0.01;, score=0.963 total time=   1.2s
# [CV 1/5] END ...............C=1000, gamma=0.001;, score=0.962 total time=   1.8s
# [CV 2/5] END ...............C=1000, gamma=0.001;, score=0.962 total time=   3.8s
# [CV 3/5] END ...............C=1000, gamma=0.001;, score=0.963 total time=   1.6s
# [CV 4/5] END ...............C=1000, gamma=0.001;, score=0.962 total time=   1.3s
# [CV 5/5] END ...............C=1000, gamma=0.001;, score=0.962 total time=   1.9s
# [CV 1/5] END ..............C=1000, gamma=0.0001;, score=0.962 total time=   0.7s
# [CV 2/5] END ..............C=1000, gamma=0.0001;, score=0.962 total time=   2.0s
# [CV 3/5] END ..............C=1000, gamma=0.0001;, score=0.963 total time=   0.6s
# [CV 4/5] END ..............C=1000, gamma=0.0001;, score=0.962 total time=   0.8s
# [CV 5/5] END ..............C=1000, gamma=0.0001;, score=0.962 total time=   1.3s
# GridSearchCV(estimator=SVC(),
#              param_grid={'C': [0.1, 1, 10, 100, 1000],
#                          'gamma': [1, 0.1, 0.01, 0.001, 0.0001]},
#              verbose=3)

# %%
grid.best_params_
# Out:
# {'C': 1, 'gamma': 1}

# %%
y_pred1 = grid.predict(X_test_scaled)

# %% [markdown]
# **TASK: Display the confusion matrix and classification report for your model.**

# %%
from sklearn.metrics import confusion_matrix,classification_report

# %%
print(confusion_matrix(y_test,y_pred1))
# Out:
# [[  1  26]
#  [  0 623]]

# %%
print(classification_report(y_test,y_pred1))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.04      0.07        27
#            1       0.96      1.00      0.98       623
#
#     accuracy                           0.96       650
#    macro avg       0.98      0.52      0.53       650
# weighted avg       0.96      0.96      0.94       650

# %%
# Out:
# array([[ 17,  10],
#        [ 92, 531]], dtype=int64)

# %%
# Out:
#               precision    recall  f1-score   support
#
#        Fraud       0.16      0.63      0.25        27
#        Legit       0.98      0.85      0.91       623
#
#     accuracy                           0.84       650
#    macro avg       0.57      0.74      0.58       650
# weighted avg       0.95      0.84      0.88       650

# %% [markdown]
# **TASK: Finally, think about how well this model performed, would you suggest using it? Realistically will this work?**

# %%
# ANSWER: View the solutions video for full discussion on this.
